# %% [markdown]
# #
# <FONT size="10pt"> <center>API N°4 : API Professionnels du Bio</center></FONT>.

# %%
import requests
import json
import pandas as pd
import numpy as np
import tqdm
import random

import geopandas as gpd
import geoviews as gv
from geoviews import dim
gv.extension('bokeh')

from IPython.display import display
pd.options.display.max_columns = None
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# # 1 : Analyse des producteurs/vendeurs du 74

# %%
# Lien url de la request : 
link = 'https://opendata.agencebio.org/api/gouv/operateurs/?departements=74&nb=9000'

# Request du lien : 
r = requests.get(link)

# Vérificiation de la bonne lecture de l'API : (200 = Good) :
r
# Out:
# <Response [200]>

# %%
# Lecture de la request en json :
Bio = r.json()

# Visualiser un fichier json de façon plus structuré :
Bio = pd.json_normalize(Bio['items'])

# Data Frame :
Bio.head(3)
# Out:
#        id raisonSociale                        denominationcourante  \
# 0   57827         2CGMJ  CARREFOUR CONTACT LES HOUCHES - SARL 2CGMJ
# 1  133087          2H2M                                        2H2M
# 2   73767     2M DISTRI                                   2M DISTRI
#
#             siret  numeroBio telephone                           email  \
# 0  75251712800019     155907      None  carrefourleshouches@hotmail.fr
# 1  91762958600012      54171      None                            None
# 2  81854542800034       8532      None                            None
#
#   codeNAF          gerant     dateMaj telephoneCommerciale     reseau  \
# 0  47.11D            None  2024-02-18           0450544026  Carrefour
# 1  01.13Z     Marc Buttin  2024-02-19                 None
# 2  47.11D  AMADORI FRANCK  2020-02-25                 None  Carrefour
#
#                                           categories siteWebs  \
# 0  [{'id': 6, 'nom': 'Grandes surfaces généralist...       []
# ...

# %%
# Nettoyage de la DF :

# Def de récupération des noms ou les organismes dans les dico :
def RecuNoms(value) :
    ListeNoms = []

    for nbnoms in range(0, len(value)) :
        try :
            ListeNoms.append(value[nbnoms]['nom'])
        except :
            ListeNoms.append(value[nbnoms]['organisme'])

    return ListeNoms

# Récupération des noms des catégories produits via def:
Bio['categories'] = Bio['categories'].apply(RecuNoms)

# Récupération de l'url du site web :
Bio['siteWebs'] = Bio['siteWebs'].apply(lambda x : x[0]['url'] if len(x) >= 1 else 'Non Communiqué')

# Récupération des informations de localisation :
# Si vide dans cette colonnes on supprime la colonne :
Bio['len'] = Bio['adressesOperateurs'].apply(lambda x : len(x))
Bio = Bio[Bio['len'] != 0]
del Bio['len']

Bio['Ville'] = Bio['adressesOperateurs'].apply(lambda x: x[0]['ville'])
Bio['CodePostal'] = Bio['adressesOperateurs'].apply(lambda x: x[0]['codePostal'])
Bio['Latitude'] = Bio['adressesOperateurs'].apply(lambda x: x[0]['lat'])
Bio['Longitude'] = Bio['adressesOperateurs'].apply(lambda x: x[0]['long'])

del Bio['adressesOperateurs']

# Récupération des produits via une def :
Bio['productions'] = Bio['productions'].apply(RecuNoms)

# Récupération des activités via la def précédente :
Bio['activites'] = Bio['activites'].apply(RecuNoms)

# Récupération des organismes de certification :
Bio['certificats'] = Bio['certificats'].apply(RecuNoms)

# Suppression des colonnes inutiles :
Bio = Bio.drop(columns = ['siret','telephone', 'email', 'gerant', 'dateMaj', 'telephoneCommerciale', 'reseau'], axis = 1)

# %%
Bio
# Out:
#          id                    raisonSociale  \
# 0     57827                            2CGMJ
# 1    133087                             2H2M
# 2     73767                        2M DISTRI
# 3      6816                            74940
# 4     71228                99 FLAVORS FRANCE
# ..      ...                              ...
# 970   29834                      YOGOLICIOUS
# 971  133348                             ZAYA
# 972  110698                  ZINTZMEYER SINA
# 973   68859     ZOLNOWSKI WOJCIECH WLADYSLAW
# 974   31932  ZUCCARELLI REBECCA FLORENCE HEL
#
#                            denominationcourante  numeroBio codeNAF  \
# 0    CARREFOUR CONTACT LES HOUCHES - SARL 2CGMJ     155907  47.11D
# 1                                          2H2M      54171  01.13Z
# 2                                     2M DISTRI       8532  47.11D
# 3                                          None     104889    None
# 4                             99 FLAVORS FRANCE       5993  46.37Z
# ...

# %% [markdown]
# # 2 : Analyse des producteurs/vendeurs de France et DOM/TOM

# %% [markdown]
# ## 2.1 : Création d'une liste des départements

# %%
# Lien url de la request : 
link = 'https://geo.api.gouv.fr/departements?'

# Request du lien : 
r = requests.get(link)

# Lecture de la request en json :
Departements = r.json()

# Visualiser un fichier json de façon plus structuré :
Departements = pd.json_normalize(Departements)

# Data Frame :
Departements.head(3)
                  
# liste Départements :
ListDept = list(Departements['code'])

# %% [markdown]
# ## 2.2 : Récupération des données de toutes les régions

# %%
DFglobale = pd.DataFrame()

for dept in tqdm.tqdm(ListDept) :

    # Lien url de la request : 
    link = 'https://opendata.agencebio.org/api/gouv/operateurs/?departements={}&nb=9000'.format(dept)

    # Request du lien : 
    r = requests.get(link)

    # Vérificiation de la bonne lecture de l'API : (200 = Good) :
    if r.status_code != 200 :
        print(dept)

    # Lecture de la request en json :
    Bio = r.json()

    # Visualiser un fichier json de façon plus structuré :
    Bio = pd.json_normalize(Bio['items'])

    DFglobale = pd.concat([DFglobale, Bio])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 101/101 [17:02<00:00, 10.13s/it]

# %%
# Modification de la DF :
DFglobale.reset_index(drop = True, inplace = True)

# Nettoyage de la DF :

# Def de récupération des noms ou les organismes dans les dico :
def RecuNoms(value) :
    ListeNoms = []

    for nbnoms in range(0, len(value)) :
        try :
            ListeNoms.append(value[nbnoms]['nom'])
        except :
            ListeNoms.append(value[nbnoms]['organisme'])

    return ListeNoms

# Récupération des noms des catégories produits via def:
DFglobale['categories'] = DFglobale['categories'].apply(RecuNoms)

# Récupération de l'url du site web :
DFglobale['siteWebs'] = DFglobale['siteWebs'].apply(lambda x : x[0]['url'] if len(x) >= 1 else 'Non Communiqué')

# Récupération des informations de localisation :
# Si vide dans cette colonnes on supprime la colonne :
DFglobale['len'] = DFglobale['adressesOperateurs'].apply(lambda x : len(x))
DFglobale = DFglobale[DFglobale['len'] != 0]
del DFglobale['len']

DFglobale['Ville'] = DFglobale['adressesOperateurs'].apply(lambda x: x[0]['ville'])
DFglobale['CodePostal'] = DFglobale['adressesOperateurs'].apply(lambda x: x[0]['codePostal'])
DFglobale['Latitude'] = DFglobale['adressesOperateurs'].apply(lambda x: x[0]['lat'])
DFglobale['Longitude'] = DFglobale['adressesOperateurs'].apply(lambda x: x[0]['long'])

del DFglobale['adressesOperateurs']

# Récupération des produits via une def :
DFglobale['productions'] = DFglobale['productions'].apply(RecuNoms)

# Récupération des activités via la def précédente :
DFglobale['activites'] = DFglobale['activites'].apply(RecuNoms)

# Récupération des organismes de certification :
DFglobale['certificats'] = DFglobale['certificats'].apply(RecuNoms)

# Suppression des colonnes inutiles :
DFglobale = DFglobale.drop(columns = ['siret','telephone', 'email', 'gerant', 'dateMaj', 'telephoneCommerciale', 'reseau'], axis = 1)

# %%
TypeActivite
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 TypeActivite
#
# NameError: name 'TypeActivite' is not defined

# %%
# Création d'une table groupée par département :
DFDept = DFglobale[['activites','CodePostal']].copy()
DFDept['CodePostal'] = DFDept['CodePostal'].apply(lambda x : x[:2] if x[:2] != '97' else x[:3])

# Toutes les activités :
DFDeptGB = DFDept.groupby('CodePostal').agg('count')
DFDeptGB.columns = ['Totaux']

# Compte par activité :
TypeActivite = []
for activite in list(DFDept['activites']):
    for i in activite :
        if i not in TypeActivite :
            TypeActivite.append(i)

    # Transformation des listes en str :
DFDept['activites'] = DFDept['activites'].apply(lambda x : ', '.join(x))

    # Création d'une colonne par activité + merge :
for activite in TypeActivite :
    globals()[activite] = DFDept[DFDept['activites'].str.contains(activite)].groupby('CodePostal').agg('count')
    globals()[activite].columns = [activite]


    # Tableau final :
    DFDeptGB = pd.merge(DFDeptGB, globals()[activite], how = 'outer', right_index = True, left_index = True)
    
# Remplissage des NaNs par 0 :
DFDeptGB = DFDeptGB.fillna(0).astype(int)

DFDeptGB = DFDeptGB.reset_index()
DFDeptGB.head(3)

# %% [markdown]
# # 3 : Création d'une carte choroplètes

# %%
# Récupération des données gèographiques de la france :
url = 'https://github.com/gregoiredavid/france-geojson/raw/master/departements-version-simplifiee.geojson'
sf = gpd.read_file(url)
sf.head()

# %%
# Merge entre le données géographiques et les polygones (France Métropole) :
DFChoroplete = pd.merge(sf, DFDeptGB, left_on = 'code', right_on = 'CodePostal')
DFChoroplete.head(3)

# %%
# Création de la carte avec les données :
deps = gv.Polygons(DFChoroplete, vdims=['nom','Production'])

deps.opts(width=600, height=600, toolbar='above', color = dim('Production'), cmap='greens',
          colorbar=True, tools=['hover'], aspect='equal' )
